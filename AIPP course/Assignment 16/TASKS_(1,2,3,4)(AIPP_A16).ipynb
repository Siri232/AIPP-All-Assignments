# %%
# %pip install ipython-sql
# %load_ext sql

# Connect to SQLite database
# %sql sqlite:///library.db
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 18.2 MB/s eta 0:00:00
# ...

# %%
import prettytable

# Create a fallback DEFAULT style so ipython-sql stops crashing
prettytable.DEFAULT = prettytable.MARKDOWN
# Out:
# /tmp/ipython-input-1086670285.py:4: DeprecationWarning: the 'MARKDOWN' constant is deprecated, use the 'TableStyle' enum instead
#   prettytable.DEFAULT = prettytable.MARKDOWN

# %%
#TASK_1
# %%sql

DROP TABLE IF EXISTS Loans;
DROP TABLE IF EXISTS Books;
DROP TABLE IF EXISTS Members;

-- CREATE TABLE: Members
CREATE TABLE Members (
    member_id INT PRIMARY KEY,
    name VARCHAR(100),
    email VARCHAR(100) UNIQUE,
    join_date DATE
);

-- CREATE TABLE: Books
CREATE TABLE Books (
    book_id INT PRIMARY KEY,
    title VARCHAR(200),
    author VARCHAR(100),
    available BOOLEAN
);

-- CREATE TABLE: Loans
CREATE TABLE Loans (
    loan_id INT PRIMARY KEY,
    member_id INT,
    book_id INT,
    loan_date DATE,
    return_date DATE,
    FOREIGN KEY (member_id) REFERENCES Members(member_id),
    FOREIGN KEY (book_id) REFERENCES Books(book_id)
);
# Out:
#  * sqlite:///library.db
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# []

# %%
# %load_ext sql
# %sql sqlite:///library.db
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %%sql
# SELECT name AS table_name
# FROM sqlite_master
# WHERE type = 'table'
# ORDER BY name;
# Out:
#  * sqlite:///library.db
# Done.
# [('Books',), ('Loans',), ('Members',)]

# %%
# %%sql
# PRAGMA table_info(Members);
# Out:
#  * sqlite:///library.db
# Done.
# [(0, 'member_id', 'INT', 0, None, 1),
#  (1, 'name', 'VARCHAR(100)', 0, None, 0),
#  (2, 'email', 'VARCHAR(100)', 0, None, 0),
#  (3, 'join_date', 'DATE', 0, None, 0)]

# %%
# %load_ext sql
# %sql sqlite:///library.db
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %%sql
# DELETE FROM Loans;
# DELETE FROM Books;
# DELETE FROM Members;
#
# -- Reset auto-increment counters (SQLite)
# DELETE FROM sqlite_sequence;
# Out:
#  * sqlite:///library.db
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# (sqlite3.OperationalError) no such table: sqlite_sequence
# [SQL: -- Reset auto-increment counters (SQLite)
# DELETE FROM sqlite_sequence;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
#TASK-2
# %%sql

INSERT OR REPLACE INTO Members (member_id, name, email, join_date) VALUES
(1, 'Siri', 'siri@gmail.com', '2025-11-01'),
(2, 'Nithya', 'nithya@gmail.com', '2025-11-02'),
(3, 'Shreya', 'shreya@gmail.com', '2025-11-03');

INSERT OR REPLACE INTO Books (book_id, title, author, available) VALUES
(101, 'Introduction to Databases', 'C.J. Date', TRUE),
(102, 'The Silent Patient', 'Alex Michaelides', TRUE),
(103, 'Clean Code', 'Robert C. Martin', TRUE);

INSERT OR REPLACE INTO Loans (loan_id, member_id, book_id, loan_date, return_date) VALUES
(1, 1, 101, '2025-11-01', NULL),
(2, 2, 102, '2025-11-02', '2025-12-25'),
(3, 3, 103, '2025-11-03', '2025-12-29');
# Out:
#  * sqlite:///library.db
# 3 rows affected.
# 3 rows affected.
# 3 rows affected.
# []

# %%
#TASK_3
# %%sql
SELECT
    Members.name AS member_name,
    Books.book_id,
    Books.title,
    Books.author,
    Loans.loan_date,
    Loans.return_date
FROM Loans
JOIN Members ON Loans.member_id = Members.member_id
JOIN Books ON Loans.book_id = Books.book_id
WHERE Members.name = 'Siri';
# Out:
#  * sqlite:///library.db
# Done.
# [('Siri', 101, 'Introduction to Databases', 'C.J. Date', '2025-11-01', None)]

# %%
#TASK_4
# %%sql
UPDATE Books
SET available = FALSE
WHERE book_id = 102;
# Out:
#  * sqlite:///library.db
# 1 rows affected.
# []

# %%
#TASK_4
# %%sql
DELETE FROM Members
WHERE member_id = 2
AND member_id IN (
    SELECT member_id
    FROM Loans
    WHERE return_date IS '2025-12-25'
);
# Out:
#  * sqlite:///library.db
# 1 rows affected.
# []

# %%
#TASK_4
# %%sql
SELECT * FROM Members;
# Out:
#  * sqlite:///library.db
# Done.
# [(3, 'Shreya', 'shreya@gmail.com', '2025-11-03')]

# %%
#TASK_4
# %%sql
SELECT * FROM Loans;
# Out:
#  * sqlite:///library.db
# Done.
# [(2, 2, 102, '2025-11-02', '2025-12-25'),
#  (3, 3, 103, '2025-11-03', '2025-12-29')]

# %%
#TASK_4
# %%sql
select * from Books;
# Out:
#  * sqlite:///library.db
# Done.
# [(101, 'Introduction to Databases', 'C.J. Date', 0),
#  (102, 'The Silent Patient', 'Alex Michaelides', 0),
#  (103, 'Clean Code', 'Robert C. Martin', 1)]
